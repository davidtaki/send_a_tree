# %% [markdown]
# ## Importing the right libraries

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# ## Creating a test data set

# %%
test_set = [15, 36, 41, 14, 69, 73, 92, 56, 101, 120, 175, 191, 215, 306, 241, 392]
len(test_set)
# Out:
# 16

# %% [markdown]
# ## Turning it into pandas Series

# %%
test_set_series = pd.Series(test_set)

# %% [markdown]
# ## Plotting it (just for fun)

# %%
test_set_series.plot()

# %% [markdown]
# ## And eventually doing the regression part

# %%
x = test_set_series.index
y = test_set_series.values

# %%
coefs = np.polyfit(x, y, 1)
predict = np.poly1d(coefs)

# %%
x_test = np.linspace(0, 16)
y_pred = predict(x_test[:, None])
plt.scatter(x, y)
plt.plot(x_test, y_pred, c = 'g')
plt.show()

# %%
coefs
# Out:
# array([ 21.37794118, -26.77205882])

# %%
predict(20)
# Out:
# 400.7867647058824

# %% [markdown]
# #### R-squared

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y, predict(x))
# Out:
# 0.849203830604859

# %% [markdown]
# ## Polynomial Regression

# %%
x = test_set_series.index
y = test_set_series.values

# %%
coefs = np.polyfit(x, y, 2)
predict = np.poly1d(coefs)

# %%
x_test = np.linspace(0, 16)
y_pred = predict(x_test[:, None])
plt.scatter(x, y)
plt.plot(x_test, y_pred, c = 'r')
plt.show()

# %%
coefs
# Out:
# array([ 1.67559524, -3.75598739, 31.87377451])

# %%
predict(20)
# Out:
# 626.9921218487393
