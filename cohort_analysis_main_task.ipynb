# %%
import pandas as pd

# %%
# %load_ext sql
# %sql postgresql://davidtaki

# %%
# %%sql free_tree_events <<
# SELECT
#     user_id,
#     my_date::date AS event_date       -- cast to pure date
# FROM free_tree
# WHERE my_date BETWEEN '2024-10-25' AND '2024-11-23';
# Out:
#  * postgresql://davidtaki:***@68.183.67.3:5432/postgres
# 29440 rows affected.
# Returning data to local variable free_tree_events

# %%
free_tree_df = free_tree_events.DataFrame()
free_tree_df['event_date'] = pd.to_datetime(free_tree_df['event_date'])

# %%
first_send = (
    free_tree_df
    .groupby('user_id')['event_date']
    .min()                       # earliest event per user
    .rename('cohort_date')
    .reset_index()
)

# %%
df = free_tree_df.merge(first_send, on='user_id', how='left')
df['days_passed'] = (df['event_date'] - df['cohort_date']).dt.days
df = df[df['days_passed'].between(0, 7)]        # keep only the first 8 calendar days

# %%
global_day0 = first_send['cohort_date'].min()   # 2024‑10‑25 in your range
df['cohort'] = (
    (df['cohort_date'] - global_day0).dt.days + 1
).astype(int)

# %%
cohort_table = (
    df.groupby(['cohort', 'days_passed'])['user_id']
      .nunique()
      .unstack(fill_value=0)          # columns 0…7
      .sort_index()                   # cohorts in chronological order
)
cohort_table
# Out:
# days_passed    0   1   2   3   4   5   6   7
# cohort
# 1             78  58  37  33  25  29  28  27
# 2             66  42  31  18  19  17  18  21
# 3             65  53  33  30  27  25  22  21
# 4             91  77  45  42  34  30  35  39
# 5             93  65  34  33  18  27  29  24
# 6             88  77  53  47  37  44  40  38
# 7             86  68  40  36  33  31  32  29
# 8             94  64  37  36  27  33  29  26
# 9             74  45  24  25  26  23  21  23
# 10            82  60  33  27  31  29  29  28
# 11            92  68  42  34  37  26  30  26
# 12           110  83  50  36  42  38  37  37
# 13           107  78  45  42  40  38  37  35
# 14           104  78  42  45  36  42  38  37
# 15           103  76  40  42  38  34  36  30
# 16            87  61  44  35  31  26  31  29
# 17            77  57  38  33  31  23  24  23
# 18           112  78  41  35  36  26  30  29
# 19            95  70  41  30  30  28  27  25
# 20            97  71  38  31  37  34  29  24
# 21           114  78  50  41  47  34  39  36
# 22           110  82  46  44  38  33  40  35
# 23            90  62  39  37  32  31  33  24
# 24            96  67  45  33  31  28  26   0
# 25           114  80  47  36  36  39   0   0
# 26           121  89  59  49  45   0   0   0
# 27           121  97  61  47   0   0   0   0
# 28           113  81  50   0   0   0   0   0
# 29           120  82   0   0   0   0   0   0
# 30            96   0   0   0   0   0   0   0

# %%
styled = (
    cohort_table.style
        .background_gradient(cmap='YlOrBr')
        # use the new pandas 2.x signature: supply a string formatter instead of the old `precision=` kwarg
        .format("{:.0f}")
)

# render in the notebook
display(styled)
# Out:
# <style  type="text/css" >
#     #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row0_col0 {
#             background-color:  #fee697;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row0_col1 {
#             background-color:  #f07818;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row0_col2 {
#             background-color:  #ee7617;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row0_col3 {
#             background-color:  #df620d;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row0_col4 {
#             background-color:  #f98e23;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row0_col5 {
#             background-color:  #e3660f;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row0_col6 {
#             background-color:  #d85a09;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row0_col7 {
#             background-color:  #da5c0a;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row1_col0 {
#             background-color:  #fffee0;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row1_col1 {
#             background-color:  #feb13e;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row1_col2 {
#             background-color:  #fd9627;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row1_col3 {
#             background-color:  #fec652;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row1_col4 {
#             background-color:  #feba46;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row1_col5 {
#             background-color:  #fec14c;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row1_col6 {
#             background-color:  #feaa38;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row1_col7 {
#             background-color:  #f98d23;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row2_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row2_col1 {
#             background-color:  #f88a21;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row2_col2 {
#             background-color:  #f88b22;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row2_col3 {
#             background-color:  #ee7416;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row2_col4 {
#             background-color:  #f3801c;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row2_col5 {
#             background-color:  #f4821d;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row2_col6 {
#             background-color:  #f78921;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row2_col7 {
#             background-color:  #f98d23;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row3_col0 {
#             background-color:  #fea634;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row3_col1 {
#             background-color:  #b94303;
#             color:  #f1f1f1;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row3_col2 {
#             background-color:  #cf5004;
#             color:  #f1f1f1;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row3_col3 {
#             background-color:  #a03704;
#             color:  #f1f1f1;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row3_col4 {
#             background-color:  #d25306;
#             color:  #f1f1f1;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row3_col5 {
#             background-color:  #dd5f0c;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row3_col6 {
#             background-color:  #983404;
#             color:  #f1f1f1;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row3_col7 {
#             background-color:  #662506;
#             color:  #f1f1f1;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row4_col0 {
#             background-color:  #fe9829;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row4_col1 {
#             background-color:  #e0630d;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row4_col2 {
#             background-color:  #f6861f;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row4_col3 {
#             background-color:  #df620d;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row4_col4 {
#             background-color:  #fec14c;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row4_col5 {
#             background-color:  #ed7316;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row4_col6 {
#             background-color:  #d25306;
#             color:  #f1f1f1;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row4_col7 {
#             background-color:  #ed7316;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row5_col0 {
#             background-color:  #feb744;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row5_col1 {
#             background-color:  #b94303;
#             color:  #f1f1f1;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row5_col2 {
#             background-color:  #9b3504;
#             color:  #f1f1f1;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row5_col3 {
#             background-color:  #762a05;
#             color:  #f1f1f1;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row5_col4 {
#             background-color:  #bc4503;
#             color:  #f1f1f1;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row5_col5 {
#             background-color:  #662506;
#             color:  #f1f1f1;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row5_col6 {
#             background-color:  #662506;
#             color:  #f1f1f1;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row5_col7 {
#             background-color:  #702806;
#             color:  #f1f1f1;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row6_col0 {
#             background-color:  #fec34f;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row6_col1 {
#             background-color:  #d85a09;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row6_col2 {
#             background-color:  #e46710;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row6_col3 {
#             background-color:  #cf5004;
#             color:  #f1f1f1;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row6_col4 {
#             background-color:  #d85a09;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row6_col5 {
#             background-color:  #d75908;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row6_col6 {
#             background-color:  #b84203;
#             color:  #f1f1f1;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row6_col7 {
#             background-color:  #cd4d03;
#             color:  #f1f1f1;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row7_col0 {
#             background-color:  #fb9326;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row7_col1 {
#             background-color:  #e3660f;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row7_col2 {
#             background-color:  #ee7617;
#             color:  #000000;
#         }    #T_3761bfa6_285f_11f0_acb5_e1af4be89ed8row7_col3 {
#             background-color:  #cf5004;
#             color:  #f1f1f1;
